# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('./Adult/adult.csv')
df.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse  \
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40
# 0     Exec-managerial         Husband   White     Male      0   0   13  \
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.columns=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','target']
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   50   Self-emp-not-inc   83311   Bachelors             13  \
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male  \
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0             0             0              13   United-States   <=50K
# ...

# %%
df['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
####subset

# %%
df_country=df[df['native-country']==' Japan']
df_country
# Out:
#        age          workclass  fnlwgt      education  education-num
# 1019    41            Private  198316   Some-college             10  \
# 1118    53            Private  288020      Bachelors             13
# 1300    29            Private  419721        HS-grad              9
# 1367    52            Private  152234        HS-grad              9
# 1755    47   Self-emp-not-inc  162924      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 31756   34            Private  143582   Some-college             10
# 31829   33            Private   72338    Prof-school             15
# 32074   27                  ?  147638        Masters             14
# 32375   40            Private  306225        HS-grad              9
# 32532   54            Private  337992      Bachelors             13
#
#             marital-status        occupation    relationship
# 1019         Never-married      Craft-repair   Not-in-family  \
# ...

# %%
df_sex_men=df[df['sex']==' Male']
df_sex_men
# Out:
#        age          workclass  fnlwgt      education  education-num
# 0       50   Self-emp-not-inc   83311      Bachelors             13  \
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 8       42            Private  159449      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32556   40            Private  154374        HS-grad              9
# 32558   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship
# 0       Married-civ-spouse     Exec-managerial         Husband  \
# ...

# %%
df_sex_female=df[df['sex']==' Female']
df_sex_female
# Out:
#        age      workclass  fnlwgt      education  education-num
# 3       28        Private  338409      Bachelors             13  \
# 4       37        Private  284582        Masters             14
# 5       49        Private  160187            9th              5
# 7       31        Private   45781        Masters             14
# 11      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32545   37        Private  198216     Assoc-acdm             12
# 32548   43      State-gov  255835   Some-college             10
# 32555   27        Private  257302     Assoc-acdm             12
# 32557   58        Private  151910        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#                marital-status        occupation     relationship    race
# 3          Married-civ-spouse    Prof-specialty             Wife   Black  \
# ...

# %%
df_race=df[df['race']==' Asian-Pac-Islander']
df_race
# Out:
#        age   workclass  fnlwgt      education  education-num
# 10      30   State-gov  141297      Bachelors             13  \
# 13      40     Private  121772      Assoc-voc             11
# 26      54           ?  180211   Some-college             10
# 92      30     Private  117747        HS-grad              9
# 138     49     Private   81973   Some-college             10
# ...    ...         ...     ...            ...            ...
# 32456   33     Private  139057        Masters             14
# 32485   24     Private  216984   Some-college             10
# 32530   30           ?   33811      Bachelors             13
# 32532   54     Private  337992      Bachelors             13
# 32552   32     Private  116138        Masters             14
#
#             marital-status        occupation    relationship
# 10      Married-civ-spouse    Prof-specialty         Husband  \
# 13      Married-civ-spouse      Craft-repair         Husband
# ...

# %%
##merger

# %%
df_merger=pd.concat([df_sex_female ,df_race])
df_merger
# Out:
#        age workclass  fnlwgt      education  education-num
# 3       28   Private  338409      Bachelors             13  \
# 4       37   Private  284582        Masters             14
# 5       49   Private  160187            9th              5
# 7       31   Private   45781        Masters             14
# 11      23   Private  122272      Bachelors             13
# ...    ...       ...     ...            ...            ...
# 32456   33   Private  139057        Masters             14
# 32485   24   Private  216984   Some-college             10
# 32530   30         ?   33811      Bachelors             13
# 32532   54   Private  337992      Bachelors             13
# 32552   32   Private  116138        Masters             14
#
#                marital-status        occupation    relationship
# 3          Married-civ-spouse    Prof-specialty            Wife  \
# 4          Married-civ-spouse   Exec-managerial            Wife
# ...

# %%
df_sort=df.sort_values(by=['education-num'])
df_sort
# Out:
#        age      workclass  fnlwgt   education  education-num
# 21793   41      Local-gov  160893   Preschool              1  \
# 223     53      Local-gov  140359   Preschool              1
# 2945    31        Private  452405   Preschool              1
# 11359   53        Private  188644   Preschool              1
# 21721   49        Private  149809   Preschool              1
# ...    ...            ...     ...         ...            ...
# 25359   34      State-gov  366198   Doctorate             16
# 7142    42   Self-emp-inc  277256   Doctorate             16
# 2373    55        Private   67450   Doctorate             16
# 13923   38      State-gov   22245   Doctorate             16
# 30484   46        Private  295334   Doctorate             16
#
#             marital-status          occupation     relationship    race
# 21793        Never-married   Handlers-cleaners        Own-child   White  \
# 223          Never-married   Machine-op-inspct    Not-in-family   White
# ...

# %%
df_transpos=df.T
df_transpos
# Out:
#                               0                   1                    2
# age                              50                  38                   53  \
# workclass          Self-emp-not-inc             Private              Private
# fnlwgt                        83311              215646               234721
# education                 Bachelors             HS-grad                 11th
# education-num                    13                   9                    7
# marital-status   Married-civ-spouse            Divorced   Married-civ-spouse
# occupation          Exec-managerial   Handlers-cleaners    Handlers-cleaners
# relationship                Husband       Not-in-family              Husband
# race                          White               White                Black
# sex                            Male                Male                 Male
# capital-gain                      0                   0                    0
# ...

# %%
df_melt=pd.melt(df,id_vars=['occupation','relationship'])

# %%
df_melt
# Out:
#                 occupation    relationship variable   value
# 0          Exec-managerial         Husband      age      50
# 1        Handlers-cleaners   Not-in-family      age      38
# 2        Handlers-cleaners         Husband      age      53
# 3           Prof-specialty            Wife      age      28
# 4          Exec-managerial            Wife      age      37
# ...                    ...             ...      ...     ...
# 423275        Tech-support            Wife   target   <=50K
# 423276   Machine-op-inspct         Husband   target    >50K
# 423277        Adm-clerical       Unmarried   target   <=50K
# 423278        Adm-clerical       Own-child   target   <=50K
# 423279     Exec-managerial            Wife   target    >50K
#
# [423280 rows x 4 columns]

# %%
df_melt1=pd.melt(df,id_vars=['occupation','relationship'],value_name='value',var_name='Metric')
df_melt1
# Out:
#                 occupation    relationship  Metric   value
# 0          Exec-managerial         Husband     age      50
# 1        Handlers-cleaners   Not-in-family     age      38
# 2        Handlers-cleaners         Husband     age      53
# 3           Prof-specialty            Wife     age      28
# 4          Exec-managerial            Wife     age      37
# ...                    ...             ...     ...     ...
# 423275        Tech-support            Wife  target   <=50K
# 423276   Machine-op-inspct         Husband  target    >50K
# 423277        Adm-clerical       Unmarried  target   <=50K
# 423278        Adm-clerical       Own-child  target   <=50K
# 423279     Exec-managerial            Wife  target    >50K
#
# [423280 rows x 4 columns]

# %%
df_melt1=pd.melt(df,id_vars=['occupation','relationship'],value_vars='education')

# %%
df_melt1
# Out:
#                occupation    relationship   variable        value
# 0         Exec-managerial         Husband  education    Bachelors
# 1       Handlers-cleaners   Not-in-family  education      HS-grad
# 2       Handlers-cleaners         Husband  education         11th
# 3          Prof-specialty            Wife  education    Bachelors
# 4         Exec-managerial            Wife  education      Masters
# ...                   ...             ...        ...          ...
# 32555        Tech-support            Wife  education   Assoc-acdm
# 32556   Machine-op-inspct         Husband  education      HS-grad
# 32557        Adm-clerical       Unmarried  education      HS-grad
# 32558        Adm-clerical       Own-child  education      HS-grad
# 32559     Exec-managerial            Wife  education      HS-grad
#
# [32560 rows x 4 columns]

# %%
#casting

# %%
# # df[df=='?'].sum().sum()
# df =df.replace('?',np.nan)
# df=df.dropna()
(df.values=='?').sum()
# Out:
# 0

# %%
df_casting=pd.pivot_table(df,index=['occupation','relationship'],values='education-num')
df_casting
# Out:
#                                    education-num
# occupation        relationship
#  ?                 Husband              9.525562
#                    Not-in-family        9.236364
#                    Other-relative       8.650794
#                    Own-child            9.106814
#                    Unmarried            8.674286
# ...                                          ...
#  Transport-moving  Not-in-family        8.844444
#                    Other-relative       8.300000
#                    Own-child            9.095808
#                    Unmarried            8.630000
#                    Wife                 9.470588
#
# [87 rows x 1 columns]
