# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('./Movie/movies_metadata.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14504\3124707517.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('./Movie/movies_metadata.csv')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en  \
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
##subset##

# %%
df['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
df_en=df[df['original_language']=='en']
df_en
# Out:
#        adult                              belongs_to_collection    budget
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45459  False                                                NaN         0
# 45460  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres
# ...

# %%
df_fr=df[df['original_language']=='fr']
df_fr
# Out:
#        adult belongs_to_collection    budget
# 28     False                   NaN  18000000  \
# 32     False                   NaN         0
# 58     False                   NaN         0
# 67     False                   NaN         0
# 72     False                   NaN         0
# ...      ...                   ...       ...
# 45444  False                   NaN         0
# 45447  False                   NaN         0
# 45448  False                   NaN         0
# 45450  False                   NaN         0
# 45451  False                   NaN         0
#
#                                                   genres homepage      id
# 28     [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN     902  \
# 32     [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...      NaN   78802
# 58     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...      NaN   99040
# 67     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN    4482
# ...

# %%
df_zh=df[df['original_language']=='zh']
df_zh
# Out:
#        adult                              belongs_to_collection  budget
# 29     False                                                NaN       0  \
# 228    False                                                NaN       0
# 294    False                                                NaN  400000
# 305    False                                                NaN       0
# 321    False                                                NaN       0
# ...      ...                                                ...     ...
# 44976  False                                                NaN       0
# 44999  False                                                NaN       0
# 45382  False  {'id': 200641, 'name': 'Red Lotus Collection',...       0
# 45383  False                                                NaN       0
# 45421  False                                                NaN       0
#
#                                                   genres homepage      id
# ...

# %%
###merger

# %%
df_merger=pd.concat([df_zh,df_fr])
df_merger
# Out:
#        adult belongs_to_collection  budget
# 29     False                   NaN       0  \
# 228    False                   NaN       0
# 294    False                   NaN  400000
# 305    False                   NaN       0
# 321    False                   NaN       0
# ...      ...                   ...     ...
# 45444  False                   NaN       0
# 45447  False                   NaN       0
# 45448  False                   NaN       0
# 45450  False                   NaN       0
# 45451  False                   NaN       0
#
#                                                   genres homepage      id
# 29     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN   37557  \
# 228    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   10451
# 294    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   25296
# 305                        [{'id': 18, 'name': 'Drama'}]      NaN  159185
# ...

# %%
####sort by customer rating vote_average

# %%
df_sort=df.sort_values(by='vote_average')
df_sort.head(10)
# Out:
#        adult                              belongs_to_collection budget
# 45465  False                                                NaN      0  \
# 24507  False  {'id': 38451, 'name': 'Charlie Chan (Warner Ol...      0
# 24506  False                                                NaN      0
# 24498  False                                                NaN      0
# 24497  False                                                NaN      0
# 24463  False                                                NaN      0
# 24441  False                                                NaN      0
# 24436  False                                                NaN      0
# 24420  False                                                NaN      0
# 24545  False                                                NaN      0
#
#                                                   genres homepage      id
# 45465                                                 []      NaN  461257  \
# ...

# %%
df_transpos=df.T
df_transpos
# Out:
#                                                                    0
# adult                                                              False  \
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                     21.946943
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %%
df_melt=pd.melt(df,id_vars=['id','original_language','original_title','overview'] ,value_name='value',var_name='Metrics')
df_melt
# Out:
#             id original_language               original_title
# 0          862                en                    Toy Story  \
# 1         8844                en                      Jumanji
# 2        15602                en             Grumpier Old Men
# 3        31357                en            Waiting to Exhale
# 4        11862                en  Father of the Bride Part II
# ...        ...               ...                          ...
# 909315  439050                fa                      رگ خواب
# 909316  111109                tl          Siglo ng Pagluluwal
# 909317   67758                en                     Betrayal
# 909318  227506                en          Satana likuyushchiy
# 909319  461257                en                     Queerama
#
#                                                  overview     Metrics  value
# 0       Led by Woody, Andy's toys live happily in his ...       adult  False
# ...

# %%
df_melt1=pd.melt(df,id_vars=['id','original_language','original_title'],value_vars='overview')
df_melt1
# Out:
#            id original_language               original_title  variable
# 0         862                en                    Toy Story  overview  \
# 1        8844                en                      Jumanji  overview
# 2       15602                en             Grumpier Old Men  overview
# 3       31357                en            Waiting to Exhale  overview
# 4       11862                en  Father of the Bride Part II  overview
# ...       ...               ...                          ...       ...
# 45461  439050                fa                      رگ خواب  overview
# 45462  111109                tl          Siglo ng Pagluluwal  overview
# 45463   67758                en                     Betrayal  overview
# 45464  227506                en          Satana likuyushchiy  overview
# 45465  461257                en                     Queerama  overview
#
#                                                    value
# 0      Led by Woody, Andy's toys live happily in his ...
# ...

# %%
Casting=pd.pivot_table(df,index=['id','original_language'],values=['budget'])
Casting
# Out:
#                          budget
# id    original_language
# 0     20                    179
# 1     22                      3
# 2     20                      3
# 3     20                      3
# 4     18                      3
# ...                         ...
# 45431 20                      3
# 45432 20                      3
# 45433 3                       3
# 45434 20                      3
# 45435 18                      3
#
# [45436 rows x 1 columns]
